# %%
# Base Ilan class
class Ilan:
    def __init__(self) -> None:
        self.id = 0
        self.ad = ""
        self.tarih = ""

    def ilan_olustur(self, id: int, ad: str, tarih: str):
        """Creates an advertisement and sets its details."""
        self.id = id
        self.ad = ad
        self.tarih = tarih
        print(f"Ilan olusturuldu: ID={self.id}, Ad={self.ad}, Tarih={self.tarih}")

    def askiya_al(self):
        """Suspends the advertisement."""
        print(f"Ilan {self.id} askıya alındı.")

     def ilanı_tekrar_yayınla(self):
        self.askida= False
        print(f"Ilan {self.id} tekrar yayında.")

# Kiralik class
class Kiralik:
    def kira_sozlesmesi(self):
        """Handles rental contract processes."""
        print("Kira sozlesmesi hazirlandi.")

# Satilik class
class Satilik:
    def kredi(self):
        """Handles loan processes."""
        print("Kredi islemleri tamamlandi.")

# Rezervasyon class
class Rezervasyon:
    def rezervasyon_yap(self, musteri_ad: str):
        """Processes a reservation."""
        print(f"{musteri_ad} için rezervasyon yapıldı.")

# Ev class inherits from Ilan, Kiralik, and Satilik classes
class Ev(Ilan, Kiralik, Satilik):
    def __init__(self):
        super().__init__()
        self.tip = "Ev"  # Specifies the type of property

class ofis(Ilan, Kiralik, Satilik):
    def __init__(self):
        super().__init__()
        self.tip = "ofis"

class turistik(Ilan, Rezervasyon):
    def __init__(self,musteri_ad):
        super().__init__()
        self.tip = "turistik"
        
# Example usage
if __name__ == "__main__":
    ev1 = Ev()  # Create an instance of Ev
    ev1.ilan_olustur(1, "Sehir Merkezinde 3+1 Daire", "2024-11-16")
    ev1.kira_sozlesmesi()
    ev1.kredi()
    ev1.askiya_al()
    ofis1=ofis()
    ofis1.ilan_olustur(2,"şehir merkezinde ofis","2023-12-5")
    rez1=Rezervasyon()
    rez1.rezervasyon_yap("emin akif")
